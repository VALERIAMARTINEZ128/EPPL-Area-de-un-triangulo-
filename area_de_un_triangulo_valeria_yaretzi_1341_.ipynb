# %% [markdown]
# <a href="https://colab.research.google.com/github/VALERIAMARTINEZ128/EPPL-Area-de-un-triangulo-/blob/main/area_de_un_triangulo_valeria_yaretzi_1341_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### valeria yaretzi lopez martinez NC = 2530805128**1341** ✨
# ### fecha 25/marzo/2026
# #### NL = 32
# ---
# ## calcular el area de un triangulo
# ![Logo de Markdown](https://raw.githubusercontent.com/VALERIAMARTINEZ128/EPPL-Area-de-un-triangulo-/refs/heads/main/triangulo.png)
#
# ## Formula para calcular Area
# * $A  = (B * H) / 2 $
#
# ---
#  ## datos de entrada
#  * $B$ ?
# *  $H$ ?
#
# ---
# ## Diagrama de flujo en lucidchart
#
# ![Logo de Markdown](https://raw.githubusercontent.com/VALERIAMARTINEZ128/EPPL-Area-de-un-triangulo-/refs/heads/main/Diagrama%20en%20blanco.png)
#
#
# ---

# %%
# calcular area de triangulo
# obtener altura y guardar en variable H
# obtener  base y guardar en variable B
# obtener area con formula A = (B*H)/2
print("calcular el area de un triangulo")
H = float(input("ingresa la altura: "))
B = float(input("ingresa la base: "))
A = (B*H)/2
print("el area del triangulo es: ", A)
print("programa terminado por valeria yaretzi lopez NL = 32")
# Out:
# calcular el area de un triangulo
# ingresa la altura: 7
# ingresa la base: 9
# el area del triangulo es:  31.5
# programa terminado por valeria yaretzi lopez NL = 32

# %% [markdown]
# ## comparacion de codigo y DF tldraw
#
#
# ![Logo de Markdown](https://raw.githubusercontent.com/VALERIAMARTINEZ128/EPPL-Area-de-un-triangulo-/refs/heads/main/diagrama%20de%20dibujo.PNG)
